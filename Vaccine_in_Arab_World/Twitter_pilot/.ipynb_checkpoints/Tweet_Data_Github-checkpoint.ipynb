# %% [markdown]
# ## Use this code to source the data from twitter.
# ## The code wil have to be run twice - adjust the dates for pre and post data

# %%
from datetime import datetime, timedelta
import pandas as pd
import pprint
import re 

def date_range(start, end):
    delta = end - start  # as timedelta
    days = [start + timedelta(days=i) for i in range(delta.days + 1)]
    return days

# start_date = datetime(2021, 7, 1)
# end_date = datetime(2021, 10, 24)

start_date = datetime(2019, 12, 1)
end_date = datetime(2020, 1, 1)
 
my_dates = date_range(start_date, end_date)
# for day in my_dates:
#     print(day)

    
import tweepy
import time

client = tweepy.Client( bearer_token='AAAAAAAAAAAAAAAAAAAAAE8dbwEAAAAABvNxooVf915gu%2BmtocSXLhnfYK8%3DUzV29whlhV88jczMhtifg0TgynlfC2Z3YTS4e5Vvubfugn9tXk')
# Replace with your own search query
query = "لقاحات OR تطعيم OR لقاح OR تطعيمات"

# tweets = client.search_all_tweets(query=query, 
#                                   tweet_fields=['author_id', 'geo', 'id', 'text', 'created_at'],
#                                   start_time='2021-7-01T00:00:00Z',
#                                   end_time='2021-7-31T00:00:00Z', max_results=500)

bdf = pd.DataFrame()

for day in my_dates:

    start_time = day.strftime("%Y-%m-%dT%H:%M:%HZ")
    day = day + timedelta(seconds=86399)
    end_time =   day.strftime("%Y-%m-%dT%H:%M:%HZ")
    print(start_time, end_time)
    
    tweets = client.search_all_tweets(query=query, 
                                      tweet_fields=['author_id', 'geo', 'id', 'text', 'created_at'],
                                      start_time=start_time,
                                      end_time=end_time, max_results=500)
    df = pd.DataFrame(data=tweets.data)
    print(start_time, end_time, len(df))
    bdf = bdf.append(df, ignore_index = True)
    time.sleep(2)

bdf.to_csv('omicron_data_2019_12_01.csv')
print(len(bdf))
# Out:
# 2019-12-01T00:00:00Z 2019-12-01T23:59:23Z
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[4], line 43
#      40 end_time =   day.strftime("%Y-%m-%dT%H:%M:%HZ")
#      41 print(start_time, end_time)
# ---> 43 tweets = client.search_all_tweets(query=query,
#      44                                   tweet_fields=['author_id', 'geo', 'id', 'text', 'created_at'],
#      45                                   start_time=start_time,
#      46                                   end_time=end_time, max_results=500)
#      47 df = pd.DataFrame(data=tweets.data)
#      48 print(start_time, end_time, len(df))
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/client.py:565, in Client.search_all_tweets(self, query, **params)
#     487 """search_all_tweets( \
#     488     query, *, end_time, expansions, max_results, media_fields, \
#     489     next_token, place_fields, poll_fields, since_id, start_time, \
#    (...)
#     562 .. _pagination: https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/paginate
#     563 """
#     564 params["query"] = query
# --> 565 return self._make_request(
#     566     "GET", "/2/tweets/search/all", params=params,
#     567     endpoint_parameters=(
#     568         "end_time", "expansions", "max_results", "media.fields",
#     569         "next_token", "place.fields", "poll.fields", "query",
#     570         "since_id", "start_time", "tweet.fields", "until_id",
#     571         "user.fields"
#     572     ), data_type=Tweet
#     573 )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/client.py:165, in Client._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     162     if param_name not in endpoint_parameters:
#     163         log.warn(f"Unexpected parameter: {param_name}")
# --> 165 response = self.request(method, route, params=request_params,
#     166                         json=json, user_auth=user_auth)
#     168 if self.return_type is requests.Response:
#     169     return response
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/tweepy/client.py:123, in Client.request(self, method, route, params, json, user_auth)
#     121     raise Unauthorized(response)
#     122 if response.status_code == 403:
# --> 123     raise Forbidden(response)
#     124 # Handle 404?
#     125 if response.status_code == 429:
#
# Forbidden: 403 Forbidden
